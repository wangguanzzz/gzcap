# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#%matplotlib inline

# %%
result=pd.read_csv('result/result.csv')
result.head()
sharpe=result['return'].mean()/result['return'].std()
print(sharpe)
# Out:
# 0.032298852590132425

# %%
meaningresult = result[result['return'] != 0]
meaningresult.sort_values(by='date')
# Out:
#             date    return
# 3     2010/01/07 -0.051236
# 10    2010/01/18 -0.050057
# 21    2010/02/02 -0.057706
# 23    2010/02/04  0.075334
# 30    2010/02/22  0.082489
# ...          ...       ...
# 2423  2019/09/24  0.051355
# 2425  2019/09/26  0.058462
# 2453  2019/11/12 -0.061047
# 2470  2019/12/05  0.049927
# 2480  2019/12/19  0.059778
#
# [393 rows x 2 columns]

# %%
meaningresult['return'].plot(kind='kde')
